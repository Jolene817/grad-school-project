# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# pid - nuke it

# %%
y = df.Survived

# %%
# pclass good as is

# %%
# skip name

# %%
df['is_female'] = pd.get_dummies(X.Sex)['female']

# %%
X = df.drop(columns=['PassengerId','Survived','Name','Sex'])
X.head()
# Out:
#    Pclass   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0       3  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1       1  38.0      1      0          PC 17599  71.2833   C85        C
# 2       3  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3       1  35.0      1      0            113803  53.1000  C123        S
# 4       3  35.0      0      0            373450   8.0500   NaN        S
#
#    is_female ager
# 0          0    1
# 1          1    2
# 2          1    1
# 3          1    2
# 4          0    2

# %%
df['ager']=pd.cut(X.Age, 3, labels=[1,2,3])
X = X.drop(columns=['Age'])
X.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-9bc1476c7366> in <module>
# ----> 1 df['ager']=pd.cut(X.Age, 3, labels=[1,2,3])
#       2 X = X.drop(columns=['Age'])
#       3 X.head()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Age'

# %%
X['fam_size'] = X.SibSp + X.Parch
X.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-a8896ed2ca77> in <module>
# ----> 1 X['fam_size'] = X.SibSp + X.Parch
#       2 X = X.drop(columns=['Sex'])
#       3 X.head()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'SibSp'

# %%
X = X.drop(columns=['Sex'])
X.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name            Ticket  \
# 0                            Braund, Mr. Owen Harris         A/5 21171
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...          PC 17599
# 2                             Heikkinen, Miss. Laina  STON/O2. 3101282
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)            113803
# 4                           Allen, Mr. William Henry            373450
#
#       Fare Cabin Embarked  is_female ager  fam_size
# 0   7.2500   NaN        S          0    1         1
# 1  71.2833   C85        C          1    2         1
# 2   7.9250   NaN        S          1    1         0
# 3  53.1000  C123        S          1    2         1
# 4   8.0500   NaN        S          0    2         0

# %%
X['Embarked'] = pd.Categorical(X.Embarked, ordered=True).codes
X.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name            Ticket  \
# 0                            Braund, Mr. Owen Harris         A/5 21171
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...          PC 17599
# 2                             Heikkinen, Miss. Laina  STON/O2. 3101282
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)            113803
# 4                           Allen, Mr. William Henry            373450
#
#       Fare Cabin  Embarked  is_female ager  fam_size
# 0   7.2500   NaN         2          0    1         1
# 1  71.2833   C85         0          1    2         1
# 2   7.9250   NaN         2          1    1         0
# 3  53.1000  C123         2          1    2         1
# 4   8.0500   NaN         2          0    2         0

# %%
X = X.drop(columns=['Ticket'])
X.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Fare Cabin  Embarked  \
# 0                            Braund, Mr. Owen Harris   7.2500   NaN         2
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833   C85         0
# 2                             Heikkinen, Miss. Laina   7.9250   NaN         2
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000  C123         2
# 4                           Allen, Mr. William Henry   8.0500   NaN         2
#
#    is_female ager  fam_size
# 0          0    1         1
# 1          1    2         1
# 2          1    1         0
# 3          1    2         1
# 4          0    2         0

# %%
X['Cabin'] = X.Cabin.map(lambda c: 0 if pd.isna(c) else ord(c[0]))
X.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Fare  Cabin  \
# 0                            Braund, Mr. Owen Harris   7.2500      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833     67
# 2                             Heikkinen, Miss. Laina   7.9250      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000     67
# 4                           Allen, Mr. William Henry   8.0500      0
#
#    Embarked  is_female ager  fam_size
# 0         2          0    1         1
# 1         0          1    2         1
# 2         2          1    1         0
# 3         2          1    2         1
# 4         2          0    2         0
